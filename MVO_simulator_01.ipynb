# %% [markdown]
# # 평균-분산 최적화(Mean-Variance Optimization) 모형 시뮬레이터(1)
# 청산조건 발생시 해당 종목 매도 후 다음 리밸런싱 때까지 현금으로 보유

# %%
import math
import numpy as np
import pandas as pd
import scipy.optimize as sco
import platform
import datetime as dt
import matplotlib.pyplot as plt
from multiprocessing import Pool # 멀티프로세싱
from matplotlib import font_manager, rc
from glob import glob # 폴더 내의 파일들을 리스트로 반환

# %% [markdown]
# # 예스트레이더 출력 결과물을 Pandas 형태로 포맷 변환

# %%
# 예스트레이더 종목검색 결과를 날짜 기준으로 포맷팅
def convert_yes_price_file(gubun):
    # 우리나라 시간 = 그리니치 표준시 + 9시
    file_dt = (dt.datetime.now() + dt.timedelta(hours=9)).strftime('%Y%m%d')

    yes_price_file = pd.DataFrame()
    # 예스트레이더 출력용 지표식과 칼럼수 일치시켜야 함.
    yes_price_file = pd.read_csv('yes_stock_price_' + file_dt + '.csv',encoding= 'euc-kr',
                           names = ['날짜1','종목명','종목코드','날짜','시가','고가','저가','종가','거래량',
                                    '단기이평','중기이평','장기이평','지수단기이평','지수중기이평','지수장기이평',
                                    'MACD','MACD_OSC','ATR','CCI','StoK','StoD','TRIX','이격도'],
                           index_col= 1, header=None, dtype={'종목코드':str})

    종목명 = yes_price_file.index.unique()
    종목코드 = yes_price_file['종목코드'].unique()  # 종목코드 사용할 경우를 위해 별도 저장
    df1 = {'종목명':종목명,
           '종목코드':종목코드}
    df1 = pd.DataFrame(df1)
    df1.to_csv('symbol_cd.csv')

    cls_p_data = pd.DataFrame()
    vol_data = pd.DataFrame()
    if gubun == 1:
        hi_p_data = pd.DataFrame()
        lo_p_data = pd.DataFrame()
        sma_data = pd.DataFrame()
        mma_data = pd.DataFrame()
        lma_data = pd.DataFrame()
        sema_data = pd.DataFrame()
        mema_data = pd.DataFrame()
        lema_data = pd.DataFrame()
        macd_data = pd.DataFrame()
        macdo_data = pd.DataFrame()
        atr_data = pd.DataFrame()
        cci_data = pd.DataFrame()
        stok_data = pd.DataFrame()
        stod_data = pd.DataFrame()
        trix_data = pd.DataFrame()
        dis_data = pd.DataFrame()

    for i in range(len(종목명)):
        cls_p = yes_price_file.loc[종목명[i],['날짜','종가']]
        cls_p.set_index(['날짜'],inplace=True)
        cls_p_data = pd.concat([cls_p_data,cls_p],axis=1) 

        vol = yes_price_file.loc[종목명[i],['날짜','거래량']]
        vol.set_index(['날짜'],inplace=True)
        vol_data = pd.concat([vol_data,vol],axis=1) 

        if gubun == 1:
            hi_p = yes_price_file.loc[종목명[i],['날짜','고가']]
            hi_p.set_index(['날짜'],inplace=True)
            hi_p_data = pd.concat([hi_p_data,hi_p],axis=1) 

            lo_p = yes_price_file.loc[종목명[i],['날짜','저가']]
            lo_p.set_index(['날짜'],inplace=True)
            lo_p_data = pd.concat([lo_p_data,lo_p],axis=1) 

            sma = yes_price_file.loc[종목명[i],['날짜','단기이평']]
            sma.set_index(['날짜'],inplace=True)
            sma_data = pd.concat([sma_data,sma],axis=1) 

            mma = yes_price_file.loc[종목명[i],['날짜','중기이평']]
            mma.set_index(['날짜'],inplace=True)
            mma_data = pd.concat([mma_data,mma],axis=1) 

            lma = yes_price_file.loc[종목명[i],['날짜','장기이평']]
            lma.set_index(['날짜'],inplace=True)
            lma_data = pd.concat([lma_data,lma],axis=1) 

            atr = yes_price_file.loc[종목명[i],['날짜','ATR']]
            atr.set_index(['날짜'],inplace=True)
            atr_data = pd.concat([atr_data,atr],axis=1) 

    cls_p_data.columns = 종목명
    print('\n 종가데이터 \n', cls_p_data.head())
    cls_p_data.to_csv('cls_p_data.csv')

    vol_data.columns = 종목명
    print('\n 거래량 \n', vol_data.head())
    vol_data.to_csv('volume_data.csv')

    if gubun == 1:
        hi_p_data.columns = 종목명
        print('\n 고가데이터 \n', hi_p_data.head())
        hi_p_data.to_csv('hi_p_data.csv')

        lo_p_data.columns = 종목명
        print('\n 저가데이터 \n', lo_p_data.head())
        lo_p_data.to_csv('lo_p_data.csv')

        sma_data.columns = 종목명
        print('\n 단기이평 \n', sma_data.head())
        sma_data.to_csv('sma_data.csv')

        mma_data.columns = 종목명
        print('\n 중기이평 \n', mma_data.head())
        mma_data.to_csv('mma_data.csv')

        lma_data.columns = 종목명
        print('\n 장기이평 \n', lma_data.head())
        lma_data.to_csv('lma_data.csv')

        atr_data.columns = 종목명
        print('\n ATR \n', atr_data.head())
        atr_data.to_csv('atr_data.csv')

# %%
gubun = 1 # 지표 파일을 만들려면 1로, 안 만들여면 0
          # 청산로직을 반영하려면 지표 파일도 생성해야 한다.
convert_yes_price_file(gubun)
# Out:
#  종가데이터
#  종목명          나노메딕스     필룩스     부산산업   카리스국보  ...   웰바이오텍    일신석재     남광토건    삼일제약
# 날짜                                           ...
# 20151021.0  2585.0  2233.0  32200.0  1508.0  ...  2675.0  1430.0  11050.0  6790.0
# 20151022.0  2560.0  2180.0  31650.0  1546.0  ...  2485.0  1340.0  10800.0  6675.0
# 20151023.0  2650.0  2228.0  31900.0  1496.0  ...  2590.0  1365.0  11300.0  6733.0
# 20151026.0  2560.0  2233.0  33600.0  1442.0  ...  2690.0  1330.0  11150.0  6733.0
# 20151027.0  3100.0  2233.0  33350.0  1521.0  ...  2730.0  1355.0  10950.0  6685.0
#
# [5 rows x 11 columns]
#
#  거래량
#  종목명             나노메딕스       필룩스     부산산업  ...       일신석재       남광토건     삼일제약
# 날짜                                        ...
# 20151021.0   361653.0  236541.0   6717.0  ...  5393439.0  1294705.0   9390.0
# 20151022.0   428860.0  122246.0  10386.0  ...  3597828.0   451290.0   9676.0
# 20151023.0   276305.0   64824.0   5114.0  ...  2415893.0   451061.0  26988.0
# 20151026.0   326127.0   76391.0  21006.0  ...  1974564.0   446795.0  24682.0
# 20151027.0  2791752.0   69859.0   6601.0  ...  2477618.0   601643.0   9514.0
#
# [5 rows x 11 columns]
#
#  고가데이터
#  종목명          나노메딕스     필룩스     부산산업   카리스국보  ...   웰바이오텍    일신석재     남광토건    삼일제약
# 날짜                                           ...
# 20151021.0  2685.0  2272.0  33150.0  1508.0  ...  2805.0  1475.0  12400.0  6790.0
# 20151022.0  2655.0  2248.0  32900.0  1803.0  ...  2715.0  1435.0  11150.0  6800.0
# 20151023.0  2740.0  2238.0  32400.0  1525.0  ...  2590.0  1365.0  11450.0  6934.0
# 20151026.0  2780.0  2272.0  34750.0  1496.0  ...  2715.0  1375.0  11800.0  6876.0
# 20151027.0  3275.0  2248.0  33650.0  1571.0  ...  2930.0  1385.0  11250.0  6771.0
#
# [5 rows x 11 columns]
#
#  저가데이터
#  종목명          나노메딕스     필룩스     부산산업   카리스국보  ...   웰바이오텍    일신석재     남광토건    삼일제약
# 날짜                                           ...
# 20151021.0  2500.0  2185.0  32150.0  1409.0  ...  2570.0  1395.0  10350.0  6704.0
# 20151022.0  2470.0  2180.0  31500.0  1479.0  ...  2450.0  1340.0  10600.0  6675.0
# 20151023.0  2500.0  2185.0  31300.0  1467.0  ...  2455.0  1320.0  10700.0  6733.0
# 20151026.0  2550.0  2199.0  31900.0  1421.0  ...  2580.0  1315.0  10900.0  6628.0
# 20151027.0  2520.0  2219.0  32600.0  1442.0  ...  2660.0  1315.0  10550.0  6628.0
#
# [5 rows x 11 columns]
#
#  단기이평
#  종목명          나노메딕스     필룩스     부산산업   카리스국보  ...   웰바이오텍    일신석재     남광토건    삼일제약
# 날짜                                           ...
# 20151021.0  2535.0  2173.0  31480.0  1442.6  ...  2749.0  1476.0  10880.0  6704.0
# 20151022.0  2577.0  2181.8  32040.0  1456.8  ...  2732.0  1438.0  10800.0  6713.4
# 20151023.0  2599.0  2198.2  32110.0  1471.8  ...  2672.0  1405.0  10860.0  6725.0
# 20151026.0  2591.0  2213.6  32420.0  1481.8  ...  2622.0  1380.0  10960.0  6732.8
# 20151027.0  2691.0  2221.4  32540.0  1502.6  ...  2634.0  1364.0  11050.0  6723.2
#
# [5 rows x 11 columns]
#
#  중기이평
#  종목명           나노메딕스      필룩스     부산산업  ...     일신석재     남광토건     삼일제약
# 날짜                                     ...
# 20151021.0  2320.00  2157.45  29805.0  ...  1228.25  10772.5  6720.30
# 20151022.0  2352.25  2166.65  29910.0  ...  1241.25  10710.0  6701.15
# 20151023.0  2389.25  2177.50  30042.5  ...  1254.75  10727.5  6686.35
# 20151026.0  2421.50  2183.05  30317.5  ...  1267.75  10767.5  6685.90
# 20151027.0  2482.50  2186.90  30560.0  ...  1281.25  10770.0  6680.65
#
# [5 rows x 11 columns]
#
#  장기이평
#  종목명           나노메딕스      필룩스      부산산업  ...     일신석재      남광토건     삼일제약
# 날짜                                      ...
# 20151021.0  2170.25  2075.18  30175.00  ...  1135.77  12460.83  7019.52
# 20151022.0  2181.75  2073.65  30142.50  ...  1139.10  12400.83  6985.72
# 20151023.0  2195.83  2074.13  30135.83  ...  1143.27  12359.17  6960.70
# 20151026.0  2207.92  2075.50  30167.50  ...  1147.10  12325.83  6940.30
# 20151027.0  2230.25  2076.70  30195.83  ...  1151.18  12288.33  6919.10
#
# [5 rows x 11 columns]
#
#  ATR
#  종목명          나노메딕스    필룩스    부산산업   카리스국보  ...   웰바이오텍   일신석재   남광토건    삼일제약
# 날짜                                         ...
# 20151021.0  215.25  74.65  1177.5   98.45  ...  148.25  81.75  820.0  176.55
# 20151022.0  222.00  75.65  1197.5  107.80  ...  159.50  85.00  760.0  167.50
# 20151023.0  228.00  77.35  1207.5  107.00  ...  163.25  86.00  720.0  169.45
# 20151026.0  235.25  70.85  1287.5  106.40  ...  168.25  87.50  712.5  166.05
# 20151027.0  268.25  63.60  1302.5  109.35  ...  175.00  89.75  700.0  165.55
#
# [5 rows x 11 columns]

# %% [markdown]
# # 전역 변수 선언

# %%
# 전역변수 선언
raw_data = pd.DataFrame()
cls_p_data = pd.DataFrame()
hi_p_data = pd.DataFrame()
lo_p_data = pd.DataFrame()
vol_data = pd.DataFrame()
atr_data = pd.DataFrame()
보유수량_테이블 = pd.DataFrame()
진입가격_테이블 = pd.DataFrame()
MP비중_테이블 = pd.DataFrame()
평가금액_테이블 = pd.DataFrame()
진입후최고가 = pd.DataFrame()
칼럼명 = []
최초투입자금 = 100000000
etf_yes_no = False
진입수수료율 = 0.002  # 진입수수료율
청산수수료율 = 0.002 if etf_yes_no else 0.005 # 청산수수료율
진입슬리피지 = 1  # 집입슬리피지 n틱
청산슬리피지 = 1  # 청산슬리피지 n틱
시장구분 = 1  # 1:kospi,  2:kosdaq
포트가공기간 = 0
debug_mode = False

# %% [markdown]
# # 사용자 함수 선언

# %%
def calc_tick(price, k_q_gubun):
    # 호가단위
    tick_size = 0
    if k_q_gubun == 1:  # 1: kospi
        if price < 1000:
            tick_size = 1
        elif price < 5000:
            tick_size = 5
        elif price < 10000:
            tick_size = 10
        elif price < 50000:
            tick_size = 50
        elif price < 100000:
            tick_size = 100
        elif price < 500000:
            tick_size = 500
        else:
            tick_size = 1000
    elif k_q_gubun == 2:  # 2: kosdaq
        if price < 1000:
            tick_size = 1
        elif price < 5000:
            tick_size = 5
        elif price < 10000:
            tick_size = 10
        elif price < 50000:
            tick_size = 50
        else:
            tick_size = 100
    return tick_size

# %%
def statistics(w,r,c):
    '''포트폴리오 총계치 출력
    인수
    =====
    w : array-like  포트폴리오 내의 비중
    
    반환값
    ======
    portfolio_return     : float 포트폴리오 수익률 기댓값
    portfolio_volatility : float 포트폴리오 변동성 기댓값
    sharpe_ratio         : float 무위험 이자율이 0일 때의 샤프 지수
    '''
    w = np.array(w)
    portfolio_return = np.sum(r * w)
    portfolio_volatility = np.sqrt(np.dot(w.T,np.dot(c, w)))
    sharp_ratio = portfolio_return / portfolio_volatility
    return np.array([portfolio_return, portfolio_volatility, sharp_ratio])

# %%
def min_func_sharpe(w,r,c):
# 최소화문제에서 샤프지수 최대값을 찾으려면 샤프지수의 음수 값을 최소화하면 된다.
    return -statistics(w,r,c)[2]  # 위에서 만든 statistics의 3번째 값이 샤프지수

# %%
def min_func_variance(w,r,c):
# 분산 최소화 함수
    return statistics(w,r,c)[1]**2

# %%
def 포트폴리오생성(row_num, 청산조건발생종목):
    if debug_mode:
        print("\n 포트폴리오 생성 start")
    wt_arr = np.zeros(len(칼럼명) - 1)
    buy_list = []

    for j in range(1, len(칼럼명)):
        if 청산조건발생종목[j] == 0:  
            buy_list.append(j)  # 열번호를 리스트로 만듬

    work_data = raw_data.iloc[row_num : row_num + 포트가공기간, buy_list]
    if debug_mode:
        print(work_data.head())
    if len(buy_list) >= len(칼럼명) / 3:  # 전체 종목 중 1/3은 넘어야 리밸런싱
        로그수익률 = np.log(work_data / work_data.shift(1))
        R = 로그수익률.mean() * 252  # 연수익률
        C = 로그수익률.cov() * 252 # 공분산
        noa = len(R)
        # 제약조건
        cons = ({'type': 'eq', 'fun': lambda x: np.sum(x) - 1},
                {'type': 'ineq', 'fun': lambda x: (x >= 0.01).sum() - 4},   #매수 종목이 5 종목 이상되도록 조건 설정 
                {'type': 'ineq', 'fun': lambda x: (x >= 0.01).sum() - 3},
                {'type': 'ineq', 'fun': lambda x: (x >= 0.01).sum() - 2},
                {'type': 'ineq', 'fun': lambda x: (x >= 0.01).sum() - 1})
        # 범위값
        bnds = tuple((0, 1) for x in range(noa))

        opts = sco.minimize(min_func_sharpe, noa * [1. / noa, ], (R, C), method='SLSQP', bounds=bnds, constraints=cons)
        optsx = (opts['x'] * 100).round(3)  # 샤프지수 최대 포트폴리오 결과값
        jj = 0
        for j in range(len(칼럼명) - 1):
            if jj < len(buy_list):
                if debug_mode:
                    print("j = ", j, buy_list[jj], opts['x'][jj])
                if buy_list[jj] - 1 == j:  # 종목리스트는 1부터 시작했으므로
                    wt_arr[j] = opts['x'][jj]
                    jj += 1
        opt_msg = opts["success"]
    else:
        opt_msg = False
    return opt_msg, wt_arr

# %%
def 현재_평가금_계산(row_num):
    평가금액합계 = 0
    보유종목수 = 0
    for j in range(1, len(칼럼명)):
        if 보유수량_테이블.iloc[row_num, j] > 0:
            수량 = 보유수량_테이블.iloc[row_num, j]
            현재가 = cls_p_data.iloc[row_num, j]
            평가금액합계 += math.floor((현재가 * (1 - 청산수수료율) * 수량) - (수량 * 청산슬리피지 * calc_tick(현재가, 시장구분)))
            보유종목수 += 1
    return (평가금액합계 + 평가금액_테이블['현금'][row_num]), 보유종목수

# %%
def 청산조건_체크(row_num, 손절률, multi1, multi2, multi3, multi4):
    청산조건발생종목 = np.zeros(len(칼럼명))
    for j in range(1, len(칼럼명)):
        if 보유수량_테이블.iloc[row_num, j] > 0 and vol_data.iloc[row_num, j] > 0:
            매수가 = 진입가격_테이블.iloc[row_num, j]
            현재가 = cls_p_data.iloc[row_num, j]
            전일종가 = cls_p_data.iloc[row_num - 1, j]
            금일저가 = lo_p_data.iloc[row_num, j]
            최고가 = 진입후최고가.iloc[row_num, j]
            ATR = atr_data.iloc[row_num, j]
            # 순서대로 손절청산, 요요청산, 샹들리에청산, 추적청산
            if 매수가 * (1 - (손절률 / 100)) >= 금일저가 or \
               (전일종가 - (ATR * multi1) >= 금일저가) or \
               (최고가 - (ATR * multi2) >= 금일저가) or \
               (최고가 >= 매수가 + (ATR * multi3) and 최고가 - (ATR * multi4) >= 금일저가):
                청산조건발생종목[j] = 1
    return 청산조건발생종목

# %% [markdown]
# # 메인 함수

# %%
def 메인_처리(기준일, 공분산_산출기간, 리밸런싱_주기, 리밸런싱_시작월, 리밸런싱_날짜, 손절률, atrs1, atrs2, atrs3, atrs4, 차트출력):
    global raw_data, cls_p_data, hi_p_data, lo_p_data, vol_data, atr_data, 포트가공기간, 칼럼명, 보유수량_테이블, 진입가격_테이블, \
           MP비중_테이블, 평가금액_테이블, 진입후최고가

    포트가공기간 = 공분산_산출기간
    if debug_mode:
        print("시작")
    cls_p_data0 = pd.read_csv('cls_p_data.csv')
    print(cls_p_data0.head())
    hi_p_data0 = pd.read_csv('hi_p_data.csv')
    lo_p_data0 = pd.read_csv('lo_p_data.csv')
    vol_data0 = pd.read_csv('volume_data.csv')
    atr_data0 = pd.read_csv('atr_data.csv')
    시뮬레이션기간 = len(cls_p_data0[cls_p_data0.날짜 >= 기준일])
    raw_data = cls_p_data0.iloc[-(시뮬레이션기간 + 공분산_산출기간):].reset_index(drop=True,inplace=False)
    cls_p_data = cls_p_data0.iloc[-시뮬레이션기간:].reset_index(drop=True,inplace=False)
    hi_p_data = hi_p_data0.iloc[-시뮬레이션기간:].reset_index(drop=True,inplace=False)
    lo_p_data = lo_p_data0.iloc[-시뮬레이션기간:].reset_index(drop=True,inplace=False)
    vol_data = vol_data0.iloc[-시뮬레이션기간:].reset_index(drop=True,inplace=False)
    atr_data = atr_data0.iloc[-시뮬레이션기간:].reset_index(drop=True,inplace=False)
    칼럼명 = cls_p_data.columns
    noa = len(칼럼명) - 1 # 자산 수

    매매수량_테이블 = pd.DataFrame(np.zeros((시뮬레이션기간, len(칼럼명))), columns=칼럼명)  # 매수,매도수량
    매매금액_테이블 = pd.DataFrame(np.zeros((시뮬레이션기간, len(칼럼명))), columns=칼럼명)  # 매수,매도금액
    진입가격_테이블 = pd.DataFrame(np.zeros((시뮬레이션기간, len(칼럼명))), columns=칼럼명)
    보유수량_테이블 = pd.DataFrame(np.zeros((시뮬레이션기간, len(칼럼명))), columns=칼럼명)
    진입후최고가 = pd.DataFrame(np.zeros((시뮬레이션기간, len(칼럼명))), columns=칼럼명)
    보유비중_테이블 = pd.DataFrame(np.zeros((시뮬레이션기간, len(칼럼명))), columns=칼럼명)
    보유비중_테이블['현금'] = 0 # 칼럼 추가
    보유비중_테이블['리밸런싱사유'] = '' # 칼럼 추가
    리밸런싱비중칼럼 = len(칼럼명) + 1
    MP비중_테이블 = pd.DataFrame(np.zeros((시뮬레이션기간, len(칼럼명))), columns=칼럼명)
    MP비중_테이블['리밸런싱사유'] = '' # 칼럼 추가
    리밸런싱MP칼럼 = len(칼럼명)
    평가금액_테이블 = pd.DataFrame(np.zeros((시뮬레이션기간, len(칼럼명))), columns=칼럼명)
    평가금액_테이블['현금'] = 최초투입자금 # 칼럼 추가
    평가금액_테이블['합계'] = 최초투입자금 # 칼럼 추가
    평가금액_테이블['누적수익률'] = 0 # 칼럼 추가
    평가금액_테이블['로그수익률'] = 0 # 칼럼 추가
    평가금액_테이블['리밸런싱사유'] = '' # 칼럼 추가
    현금칼럼 = len(칼럼명)
    평가금액_테이블.iloc[0, 현금칼럼] = 최초투입자금  # 첫행에 현금열에 최초 투입자금 입력
    합계칼럼 = 현금칼럼 + 1
    수익률칼럼 = 합계칼럼 + 1
    로그수익칼럼 = 수익률칼럼 + 1
    리밸런싱칼럼 = 로그수익칼럼 + 1

    for i in range(시뮬레이션기간):
        yyyymmdd = cls_p_data['날짜'][i]
        yyyy = yyyymmdd // 10000
        mm = yyyymmdd // 100 - (yyyymmdd // 10000) * 100
        dd = yyyymmdd % 100
        dd1 = cls_p_data['날짜'][i + 1] % 100 if i + 1 < len(cls_p_data) else 31  # 익일 날짜
        dd0 = cls_p_data['날짜'][i - 1] % 100 if i >= 1 else 1  # 전일 날짜

        # 각 테이블의 날짜 칼럼에 날짜 업데이트
        매매수량_테이블.iloc[i, 0] = yyyymmdd
        매매금액_테이블.iloc[i, 0] = yyyymmdd
        진입가격_테이블.iloc[i, 0] = yyyymmdd
        보유수량_테이블.iloc[i, 0] = yyyymmdd
        보유비중_테이블.iloc[i, 0] = yyyymmdd
        MP비중_테이블.iloc[i, 0] = yyyymmdd
        평가금액_테이블.iloc[i, 0] = yyyymmdd
        진입후최고가.iloc[i, 0] = yyyymmdd

        if i >= 1:
            # 전일 데이터를 그대로 가져오는 테이블의 처리, 매매수량과 매매금액_테이블은 거래있을 때만 처리
            for j in range(1, len(칼럼명)):
                진입가격_테이블.iloc[i, j] = 진입가격_테이블.iloc[i - 1, j]
                보유수량_테이블.iloc[i, j] = 보유수량_테이블.iloc[i - 1, j]
                MP비중_테이블.iloc[i, j] = MP비중_테이블.iloc[i - 1, j]
                if 보유수량_테이블.iloc[i, j] > 0:
                    if 진입후최고가.iloc[i - 1, j] < hi_p_data.iloc[i, j]:
                        진입후최고가.iloc[i, j] = 진입후최고가.iloc[i - 1, j]
                    else:
                        진입후최고가.iloc[i, j] = 진입후최고가.iloc[i - 1, j]
                else:
                    진입후최고가.iloc[i, j] = 0
            평가금액_테이블.iloc[i, 현금칼럼] = 평가금액_테이블.iloc[i - 1, 현금칼럼]  # 현금
            if debug_mode:
                print("\n 현금 = ", 평가금액_테이블.iloc[i, 현금칼럼])

        청산조건발생종목 = 청산조건_체크(i, 손절률, atrs1, atrs2, atrs3, atrs4)
        if sum(청산조건발생종목) > 0:
            print(">> 날짜체크", i, yyyy, mm, dd, ", 청산조건발생")
            현금 = 평가금액_테이블.iloc[i, 현금칼럼]
            if debug_mode:
                print("현금=", 현금)
            for k in range(1, len(칼럼명)):
                # k가 1부터 시작
                현재가 = cls_p_data.iloc[i, k]
                거래량 = vol_data.iloc[i, k]
                현재수량 = 보유수량_테이블.iloc[i, k]
                if 청산조건발생종목[k] == 1 and 현재수량 > 0 and 거래량 > 0:
                    청산할수량 = 현재수량
                    청산금액 = math.floor((현재가 * (1 - 청산수수료율) * 청산할수량) -
                                          (청산할수량 * 청산슬리피지 * calc_tick(현재가, 시장구분)))
                    현금 += 청산금액
                    매매수량_테이블.iloc[i, k] = -청산할수량
                    매매금액_테이블.iloc[i, k] = 청산금액  # 현금유입
                    진입가격_테이블.iloc[i, k] = 0
                    보유수량_테이블.iloc[i, k] = 0
                    평가금액_테이블.iloc[i, 현금칼럼] = 현금
            보유비중_테이블.iloc[i, 리밸런싱비중칼럼] = '청산조건발생'
            MP비중_테이블.iloc[i, 리밸런싱MP칼럼] = '청산조건발생'
            평가금액_테이블.iloc[i, 리밸런싱칼럼] = '청산조건발생'

        # 목표비중을 계산하려면 현재가 기준으로 평가금액을 합산해 놓아야 한다.
        현재_평가금액, 보유종목수 = 현재_평가금_계산(i)

        if ((dd0 < 리밸런싱_날짜 <= dd or 리밸런싱_날짜 <= dd < dd0 or dd1 < dd <= 리밸런싱_날짜) \
            and mm % 리밸런싱_주기 == 리밸런싱_시작월) or \
            보유종목수 <= 2: 
            print(">> 날짜체크", i, yyyy, mm, dd, ", 리밸런싱발생")
            opt_result, W = 포트폴리오생성(i,청산조건발생종목)
            if opt_result == True:  # 포트폴리오 생성이 정상이라면
                현금 = 평가금액_테이블.iloc[i, 현금칼럼]
                if debug_mode:
                    print("현금 = ", 현금)
                for k in range(1, len(칼럼명)):
                    # k가 1부터 시작
                    매입가능금액 = math.floor(현재_평가금액 * W[k - 1])
                    현재가 = cls_p_data.iloc[i, k]
                    거래량 = vol_data.iloc[i, k]
                    목표수량 = math.floor(매입가능금액 / ((현재가 * (1 + 진입수수료율)) +
                                          (진입슬리피지 * calc_tick(현재가, 시장구분))))
                    현재수량 = 보유수량_테이블.iloc[i, k]
                    if debug_mode:
                        print("목표수량 = ", 목표수량, "현재수량 = ", 현재수량)
                    # 매도부터 실행해서 현금 만들고
                    if 목표수량 < 현재수량 and 거래량 > 0:
                        청산할수량 = 현재수량 - 목표수량
                        청산금액 = math.floor((현재가 * (1 - 청산수수료율) * 청산할수량) -
                                              (청산할수량 * 청산슬리피지 * calc_tick(현재가, 시장구분)))
                        현금 += 청산금액
                        if debug_mode:
                            print("자산번호 = ", k, "현금 = ", 현금)
                        매매수량_테이블.iloc[i, k] = -청산할수량
                        매매금액_테이블.iloc[i, k] = 청산금액  # 현금유입
                        진입가격_테이블.iloc[i, k] = 현재가 if 목표수량 > 0 else 0
                        보유수량_테이블.iloc[i, k] = 목표수량
                        MP비중_테이블.iloc[i, k] = (W[k - 1] * 100).round(2)
                        평가금액_테이블.iloc[i, 현금칼럼] = 현금

                for k in range(1, len(칼럼명)):
                    # k가 1부터 시작
                    매입가능금액 = math.floor(현재_평가금액 * W[k - 1])
                    현재가 = cls_p_data.iloc[i, k]
                    거래량 = vol_data.iloc[i, k]
                    목표수량 = math.floor(매입가능금액 / ((현재가 * (1 + 진입수수료율)) +
                                                (진입슬리피지 * calc_tick(현재가, 시장구분))))
                    현재수량 = 보유수량_테이블.iloc[i, k]
                    if debug_mode:
                        print("목표수량 = ", 목표수량, "현재수량 = ", 현재수량)
                    if 목표수량 > 현재수량 and 거래량 > 0:
                        매입할수량 = 목표수량 - 현재수량
                        매입금액 = math.ceil((현재가 * (1 + 진입수수료율) * 매입할수량) +
                                         (매입할수량 * 진입슬리피지 * calc_tick(현재가, 시장구분)))
                        if debug_mode:
                            print("자산번호 = ", k, "현금 = ", 현금)
                        # 매도실패로 현금이 부족하면
                        if 매입금액 > 현금:   
                            매입할수량 = math.floor(현금 / ((현재가 * (1 + 진입수수료율)) +
                                                (진입슬리피지 * calc_tick(현재가, 시장구분))))
                            매입금액 = math.ceil((현재가 * (1 + 진입수수료율) * 매입할수량) +
                                                (매입할수량 * 진입슬리피지 * calc_tick(현재가, 시장구분)))
                            목표수량 = 현재수량 + 매입할수량
                        현금 -= 매입금액
                        매매수량_테이블.iloc[i, k] = 매입할수량
                        매매금액_테이블.iloc[i, k] = -매입금액  # 현금지출
                        진입가격_테이블.iloc[i, k] = 현재가  # 매수평균가가 아니라 리밸런싱한 날의 현재가를 저장
                        보유수량_테이블.iloc[i, k] = 목표수량  # 매수면 수량 증가
                        MP비중_테이블.iloc[i, k] = (W[k - 1] * 100).round(2)
                        평가금액_테이블.iloc[i, 현금칼럼] = 현금
                    elif 목표수량 > 0 and 목표수량 == 현재수량:
                        진입가격_테이블.iloc[i, k] = 현재가  # 매수평균가가 아니라 리밸런싱한 날의 현재가를 저장
                        MP비중_테이블.iloc[i, k] = (W[k - 1] * 100).round(2)
                    else:
                        MP비중_테이블.iloc[i, k] = (W[k - 1] * 100).round(2)
                        
                if sum(청산조건발생종목) == 0:
                    보유비중_테이블.iloc[i, 리밸런싱비중칼럼] = '정기'
                    MP비중_테이블.iloc[i, 리밸런싱MP칼럼] = '정기'
                    평가금액_테이블.iloc[i, 리밸런싱칼럼] = '정기'

        평가금액합계 = 0
        for j in range(1, len(칼럼명)):
            if 보유수량_테이블.iloc[i, j] > 0:
                수량 = 보유수량_테이블.iloc[i, j]
                현재가 = cls_p_data.iloc[i, j]
                평가금액 = math.floor((현재가 * (1 - 청산수수료율) * 수량) - (수량 * 청산슬리피지 * calc_tick(현재가, 시장구분)))
            else:
                평가금액 = 0
            평가금액_테이블.iloc[i, j] = 평가금액
            평가금액합계 += 평가금액
        평가금액_테이블.iloc[i, 합계칼럼] = 평가금액합계 + 평가금액_테이블.iloc[i, 현금칼럼]
        평가금액_테이블.iloc[i, 수익률칼럼] = (((평가금액_테이블.iloc[i, 합계칼럼] / 최초투입자금) - 1) * 100).round(2)
        if i >= 1:
            평가금액_테이블.iloc[i, 로그수익칼럼] = np.log(평가금액_테이블.iloc[i, 합계칼럼] /
                                               평가금액_테이블.iloc[i - 1, 합계칼럼])
        for j in range(1, len(칼럼명) + 1):
            보유비중_테이블.iloc[i, j] = ((평가금액_테이블.iloc[i, j] / 평가금액_테이블.iloc[i, 합계칼럼]) * 100).round(2)
        if debug_mode:
            print(i, "평가금액 =", 평가금액_테이블.iloc[i, 합계칼럼], "수익률 =", 평가금액_테이블.iloc[i, 수익률칼럼])

# 시뮬레이션 결과 보고서 만들기
    연평균수익률 = np.mean(평가금액_테이블.iloc[:, 로그수익칼럼]) * 252 * 100
    표준편차 = np.std(평가금액_테이블.iloc[:, 로그수익칼럼]) * math.sqrt(252) * 100
    샤프지수 = (연평균수익률 / 표준편차) if 표준편차 != 0 else 0

    file_list = glob('MVO1_simul_report.csv')
    if len(file_list) == 0:  # 파일이 없으면 빈 자료구조를 만들고
        시뮬_보고서 = pd.DataFrame([], columns=['운용개시일', '공분산 산출기간', '리밸런싱 주기(월)', '리밸런싱 시작월',
                                        '리밸런싱 날짜', '손절률', 'atrs1', 'atrs2', 'atrs3', 'atrs4', '누적수익률', '연수익률', '표준편차', '샤프지수'])
    else:  # 파일이 있으면 읽어들인다
        시뮬_보고서 = pd.read_csv('MVO1_simul_report.csv')

    # pandas 마지막 줄에 한 줄 추가 방법
    시뮬_보고서.loc[len(시뮬_보고서)] = [평가금액_테이블.iloc[0, 0], 공분산_산출기간, 리밸런싱_주기, 리밸런싱_시작월, \
                        리밸런싱_날짜, 손절률, atrs1, atrs2, atrs3, atrs4, 평가금액_테이블.iloc[- 1, 수익률칼럼], 연평균수익률, 표준편차, 샤프지수]
    시뮬_보고서.to_csv('MVO1_simul_report.csv', index=None)

    print('평가금액 =', 평가금액_테이블.iloc[- 1, 합계칼럼], ', 누적수익률 =', 평가금액_테이블.iloc[- 1, 수익률칼럼], \
          ', 연평균수익률 = ', round(연평균수익률, 2), ', 표준편차 =', round(표준편차, 2), ', 샤프지수 =', round(샤프지수, 2))

    파일명_머리 = 'MVO1_' + str(공분산_산출기간) + '_' + str(리밸런싱_주기) + '_' + str(리밸런싱_시작월) + '_' + \
             str(리밸런싱_날짜) + '_' + str(손절률) + '_' + str(atrs1) + '_' + str(atrs2) + '_' + str(atrs3) + '_' + str(atrs4) + '_'
#평가금액_자료 말고는 검증용
    매매금액_테이블.to_csv(파일명_머리 + 'trd_mnt.csv', index=None) # colab에서는 안 먹힘, encoding="ansi")
    매매수량_테이블.to_csv(파일명_머리 + 'trd_cont.csv', index=None)
    진입가격_테이블.to_csv(파일명_머리 + 'entry_prc.csv', index=None)
    보유수량_테이블.to_csv(파일명_머리 + 'acc_cont.csv', index=None)
    MP비중_테이블.to_csv(파일명_머리 + 'mp_weight.csv', index=None)
    보유비중_테이블.to_csv(파일명_머리 + 'real_weight.csv', index=None)
    평가금액_테이블.to_csv(파일명_머리 + 'eval.csv', index=None)

    if 차트출력 == 1:
        plt.figure(figsize=(12, 6))
        plt.plot(평가금액_테이블['누적수익률'], label = '수익률')
        plt.legend()
        plt.grid(True)
        plt.show()

# %% [markdown]
# # 메인 함수 호출

# %%
# 메인_처리(기준일, 공분산_산출기간, 리밸런싱_주기, 리밸런싱_시작월, 리밸런싱_날짜, 손절률, atrs1, atrs2, atrs3, atrs4, 차트출력)
메인_처리(20170701, 50, 1, 0, 1, 20, 1, 1, 1, 1, 1)
# Out:
#            날짜   나노메딕스     필룩스     부산산업  ...   웰바이오텍    일신석재     남광토건    삼일제약
# 0  20151021.0  2585.0  2233.0  32200.0  ...  2675.0  1430.0  11050.0  6790.0
# 1  20151022.0  2560.0  2180.0  31650.0  ...  2485.0  1340.0  10800.0  6675.0
# 2  20151023.0  2650.0  2228.0  31900.0  ...  2590.0  1365.0  11300.0  6733.0
# 3  20151026.0  2560.0  2233.0  33600.0  ...  2690.0  1330.0  11150.0  6733.0
# 4  20151027.0  3100.0  2233.0  33350.0  ...  2730.0  1355.0  10950.0  6685.0
#
# [5 rows x 12 columns]
# >> 날짜체크 0 2017.0 7.0 3.0 , 리밸런싱발생
# >> 날짜체크 1 2017.0 7.0 4.0 , 리밸런싱발생
# >> 날짜체크 2 2017.0 7.0 5.0 , 리밸런싱발생
# >> 날짜체크 3 2017.0 7.0 6.0 , 리밸런싱발생
# >> 날짜체크 4 2017.0 7.0 7.0 , 리밸런싱발생
# >> 날짜체크 5 2017.0 7.0 10.0 , 리밸런싱발생
# >> 날짜체크 6 2017.0 7.0 11.0 , 리밸런싱발생
# >> 날짜체크 7 2017.0 7.0 12.0 , 리밸런싱발생
# >> 날짜체크 8 2017.0 7.0 13.0 , 리밸런싱발생
# >> 날짜체크 9 2017.0 7.0 14.0 , 리밸런싱발생
# >> 날짜체크 10 2017.0 7.0 17.0 , 리밸런싱발생
# >> 날짜체크 11 2017.0 7.0 18.0 , 청산조건발생
# >> 날짜체크 17 2017.0 7.0 26.0 , 청산조건발생
# >> 날짜체크 17 2017.0 7.0 26.0 , 리밸런싱발생
# >> 날짜체크 18 2017.0 7.0 27.0 , 리밸런싱발생
# >> 날짜체크 19 2017.0 7.0 28.0 , 리밸런싱발생
# >> 날짜체크 20 2017.0 7.0 31.0 , 청산조건발생
# >> 날짜체크 20 2017.0 7.0 31.0 , 리밸런싱발생
# >> 날짜체크 21 2017.0 8.0 1.0 , 리밸런싱발생
# >> 날짜체크 22 2017.0 8.0 2.0 , 리밸런싱발생
# >> 날짜체크 23 2017.0 8.0 3.0 , 리밸런싱발생
# >> 날짜체크 24 2017.0 8.0 4.0 , 리밸런싱발생
# >> 날짜체크 25 2017.0 8.0 7.0 , 리밸런싱발생
# >> 날짜체크 26 2017.0 8.0 8.0 , 리밸런싱발생
# >> 날짜체크 27 2017.0 8.0 9.0 , 리밸런싱발생
# >> 날짜체크 28 2017.0 8.0 10.0 , 리밸런싱발생
# >> 날짜체크 29 2017.0 8.0 11.0 , 청산조건발생
# >> 날짜체크 29 2017.0 8.0 11.0 , 리밸런싱발생
# >> 날짜체크 30 2017.0 8.0 14.0 , 리밸런싱발생
# >> 날짜체크 31 2017.0 8.0 16.0 , 리밸런싱발생
# >> 날짜체크 32 2017.0 8.0 17.0 , 리밸런싱발생
# >> 날짜체크 33 2017.0 8.0 18.0 , 리밸런싱발생
# >> 날짜체크 34 2017.0 8.0 21.0 , 리밸런싱발생
# >> 날짜체크 35 2017.0 8.0 22.0 , 리밸런싱발생
# >> 날짜체크 36 2017.0 8.0 23.0 , 리밸런싱발생
# >> 날짜체크 37 2017.0 8.0 24.0 , 리밸런싱발생
# >> 날짜체크 38 2017.0 8.0 25.0 , 리밸런싱발생
# >> 날짜체크 39 2017.0 8.0 28.0 , 리밸런싱발생
# >> 날짜체크 40 2017.0 8.0 29.0 , 리밸런싱발생
# >> 날짜체크 41 2017.0 8.0 30.0 , 리밸런싱발생
# >> 날짜체크 42 2017.0 8.0 31.0 , 리밸런싱발생
# >> 날짜체크 43 2017.0 9.0 1.0 , 리밸런싱발생
# >> 날짜체크 44 2017.0 9.0 4.0 , 리밸런싱발생
# >> 날짜체크 45 2017.0 9.0 5.0 , 리밸런싱발생
# >> 날짜체크 46 2017.0 9.0 6.0 , 리밸런싱발생
# >> 날짜체크 47 2017.0 9.0 7.0 , 리밸런싱발생
# >> 날짜체크 48 2017.0 9.0 8.0 , 리밸런싱발생
# >> 날짜체크 49 2017.0 9.0 11.0 , 리밸런싱발생
# >> 날짜체크 50 2017.0 9.0 12.0 , 리밸런싱발생
# >> 날짜체크 51 2017.0 9.0 13.0 , 리밸런싱발생
# >> 날짜체크 52 2017.0 9.0 14.0 , 리밸런싱발생
# >> 날짜체크 53 2017.0 9.0 15.0 , 리밸런싱발생
# >> 날짜체크 54 2017.0 9.0 18.0 , 리밸런싱발생
# >> 날짜체크 55 2017.0 9.0 19.0 , 리밸런싱발생
# >> 날짜체크 56 2017.0 9.0 20.0 , 리밸런싱발생
# >> 날짜체크 57 2017.0 9.0 21.0 , 리밸런싱발생
# >> 날짜체크 58 2017.0 9.0 22.0 , 리밸런싱발생
# >> 날짜체크 59 2017.0 9.0 25.0 , 리밸런싱발생
# >> 날짜체크 60 2017.0 9.0 26.0 , 리밸런싱발생
# >> 날짜체크 61 2017.0 9.0 27.0 , 리밸런싱발생
# >> 날짜체크 62 2017.0 9.0 28.0 , 리밸런싱발생
# >> 날짜체크 63 2017.0 9.0 29.0 , 리밸런싱발생
# >> 날짜체크 64 2017.0 10.0 10.0 , 리밸런싱발생
# >> 날짜체크 65 2017.0 10.0 11.0 , 리밸런싱발생
# >> 날짜체크 66 2017.0 10.0 12.0 , 리밸런싱발생
# >> 날짜체크 67 2017.0 10.0 13.0 , 리밸런싱발생
# >> 날짜체크 68 2017.0 10.0 16.0 , 리밸런싱발생
# >> 날짜체크 69 2017.0 10.0 17.0 , 리밸런싱발생
# >> 날짜체크 70 2017.0 10.0 18.0 , 리밸런싱발생
# >> 날짜체크 71 2017.0 10.0 19.0 , 리밸런싱발생
# >> 날짜체크 72 2017.0 10.0 20.0 , 리밸런싱발생
# >> 날짜체크 73 2017.0 10.0 23.0 , 리밸런싱발생
# >> 날짜체크 74 2017.0 10.0 24.0 , 리밸런싱발생
# >> 날짜체크 75 2017.0 10.0 25.0 , 리밸런싱발생
# >> 날짜체크 76 2017.0 10.0 26.0 , 리밸런싱발생
# >> 날짜체크 77 2017.0 10.0 27.0 , 리밸런싱발생
# >> 날짜체크 78 2017.0 10.0 30.0 , 리밸런싱발생
# >> 날짜체크 79 2017.0 10.0 31.0 , 리밸런싱발생
# >> 날짜체크 80 2017.0 11.0 1.0 , 리밸런싱발생
# >> 날짜체크 81 2017.0 11.0 2.0 , 리밸런싱발생
# >> 날짜체크 82 2017.0 11.0 3.0 , 리밸런싱발생
# >> 날짜체크 83 2017.0 11.0 6.0 , 리밸런싱발생
# >> 날짜체크 84 2017.0 11.0 7.0 , 리밸런싱발생
# >> 날짜체크 85 2017.0 11.0 8.0 , 리밸런싱발생
# >> 날짜체크 86 2017.0 11.0 9.0 , 리밸런싱발생
# >> 날짜체크 87 2017.0 11.0 10.0 , 리밸런싱발생
# >> 날짜체크 88 2017.0 11.0 13.0 , 청산조건발생
# >> 날짜체크 89 2017.0 11.0 14.0 , 청산조건발생
# >> 날짜체크 89 2017.0 11.0 14.0 , 리밸런싱발생
# >> 날짜체크 90 2017.0 11.0 15.0 , 리밸런싱발생
# >> 날짜체크 91 2017.0 11.0 16.0 , 리밸런싱발생
# >> 날짜체크 92 2017.0 11.0 17.0 , 리밸런싱발생
# >> 날짜체크 93 2017.0 11.0 20.0 , 리밸런싱발생
# >> 날짜체크 94 2017.0 11.0 21.0 , 청산조건발생
# >> 날짜체크 95 2017.0 11.0 22.0 , 청산조건발생
# >> 날짜체크 95 2017.0 11.0 22.0 , 리밸런싱발생
# >> 날짜체크 96 2017.0 11.0 23.0 , 리밸런싱발생
# >> 날짜체크 97 2017.0 11.0 24.0 , 청산조건발생
# >> 날짜체크 98 2017.0 11.0 27.0 , 청산조건발생
# >> 날짜체크 99 2017.0 11.0 28.0 , 청산조건발생
# >> 날짜체크 99 2017.0 11.0 28.0 , 리밸런싱발생
# >> 날짜체크 100 2017.0 11.0 29.0 , 리밸런싱발생
# >> 날짜체크 101 2017.0 11.0 30.0 , 리밸런싱발생
# >> 날짜체크 102 2017.0 12.0 1.0 , 리밸런싱발생
# >> 날짜체크 109 2017.0 12.0 12.0 , 청산조건발생
# >> 날짜체크 116 2017.0 12.0 21.0 , 청산조건발생
# >> 날짜체크 116 2017.0 12.0 21.0 , 리밸런싱발생
# >> 날짜체크 118 2017.0 12.0 26.0 , 청산조건발생
# >> 날짜체크 120 2017.0 12.0 28.0 , 청산조건발생
# >> 날짜체크 121 2018.0 1.0 2.0 , 리밸런싱발생
# >> 날짜체크 122 2018.0 1.0 3.0 , 청산조건발생
# >> 날짜체크 126 2018.0 1.0 9.0 , 청산조건발생
# >> 날짜체크 128 2018.0 1.0 11.0 , 청산조건발생
# >> 날짜체크 131 2018.0 1.0 16.0 , 청산조건발생
# >> 날짜체크 131 2018.0 1.0 16.0 , 리밸런싱발생
# >> 날짜체크 132 2018.0 1.0 17.0 , 청산조건발생
# >> 날짜체크 135 2018.0 1.0 22.0 , 청산조건발생
# >> 날짜체크 142 2018.0 1.0 31.0 , 청산조건발생
# >> 날짜체크 142 2018.0 1.0 31.0 , 리밸런싱발생
# >> 날짜체크 143 2018.0 2.0 1.0 , 리밸런싱발생
# >> 날짜체크 144 2018.0 2.0 2.0 , 청산조건발생
# >> 날짜체크 146 2018.0 2.0 6.0 , 청산조건발생
# >> 날짜체크 146 2018.0 2.0 6.0 , 리밸런싱발생
# >> 날짜체크 147 2018.0 2.0 7.0 , 청산조건발생
# >> 날짜체크 156 2018.0 2.0 22.0 , 청산조건발생
# >> 날짜체크 156 2018.0 2.0 22.0 , 리밸런싱발생
# >> 날짜체크 160 2018.0 2.0 28.0 , 청산조건발생
# >> 날짜체크 161 2018.0 3.0 2.0 , 리밸런싱발생
# >> 날짜체크 162 2018.0 3.0 5.0 , 청산조건발생
# >> 날짜체크 164 2018.0 3.0 7.0 , 청산조건발생
# >> 날짜체크 169 2018.0 3.0 14.0 , 청산조건발생
# >> 날짜체크 170 2018.0 3.0 15.0 , 청산조건발생
# >> 날짜체크 175 2018.0 3.0 22.0 , 청산조건발생
# >> 날짜체크 176 2018.0 3.0 23.0 , 청산조건발생
# >> 날짜체크 176 2018.0 3.0 23.0 , 리밸런싱발생
# >> 날짜체크 178 2018.0 3.0 27.0 , 청산조건발생
# >> 날짜체크 179 2018.0 3.0 28.0 , 청산조건발생
# >> 날짜체크 182 2018.0 4.0 2.0 , 리밸런싱발생
# >> 날짜체크 184 2018.0 4.0 4.0 , 청산조건발생
# >> 날짜체크 188 2018.0 4.0 10.0 , 청산조건발생
# >> 날짜체크 190 2018.0 4.0 12.0 , 청산조건발생
# >> 날짜체크 194 2018.0 4.0 18.0 , 청산조건발생
# >> 날짜체크 194 2018.0 4.0 18.0 , 리밸런싱발생
# >> 날짜체크 195 2018.0 4.0 19.0 , 청산조건발생
# >> 날짜체크 196 2018.0 4.0 20.0 , 청산조건발생
# >> 날짜체크 197 2018.0 4.0 23.0 , 청산조건발생
# >> 날짜체크 197 2018.0 4.0 23.0 , 리밸런싱발생
# >> 날짜체크 198 2018.0 4.0 24.0 , 청산조건발생
# >> 날짜체크 198 2018.0 4.0 24.0 , 리밸런싱발생
# >> 날짜체크 203 2018.0 5.0 2.0 , 리밸런싱발생
# >> 날짜체크 206 2018.0 5.0 8.0 , 청산조건발생
# >> 날짜체크 207 2018.0 5.0 9.0 , 청산조건발생
# >> 날짜체크 209 2018.0 5.0 11.0 , 청산조건발생
# >> 날짜체크 212 2018.0 5.0 16.0 , 청산조건발생
# >> 날짜체크 218 2018.0 5.0 25.0 , 청산조건발생
# >> 날짜체크 218 2018.0 5.0 25.0 , 리밸런싱발생
# >> 날짜체크 219 2018.0 5.0 28.0 , 청산조건발생
# >> 날짜체크 220 2018.0 5.0 29.0 , 청산조건발생
# >> 날짜체크 223 2018.0 6.0 1.0 , 리밸런싱발생
# >> 날짜체크 224 2018.0 6.0 4.0 , 청산조건발생
# >> 날짜체크 229 2018.0 6.0 12.0 , 청산조건발생
# >> 날짜체크 230 2018.0 6.0 14.0 , 청산조건발생
# >> 날짜체크 231 2018.0 6.0 15.0 , 청산조건발생
# >> 날짜체크 231 2018.0 6.0 15.0 , 리밸런싱발생
# >> 날짜체크 232 2018.0 6.0 18.0 , 청산조건발생
# >> 날짜체크 234 2018.0 6.0 20.0 , 청산조건발생
# >> 날짜체크 239 2018.0 6.0 27.0 , 청산조건발생
# >> 날짜체크 239 2018.0 6.0 27.0 , 리밸런싱발생
# >> 날짜체크 240 2018.0 6.0 28.0 , 리밸런싱발생
# >> 날짜체크 241 2018.0 6.0 29.0 , 청산조건발생
# >> 날짜체크 242 2018.0 7.0 2.0 , 리밸런싱발생
# >> 날짜체크 247 2018.0 7.0 9.0 , 청산조건발생
# >> 날짜체크 247 2018.0 7.0 9.0 , 리밸런싱발생
# >> 날짜체크 248 2018.0 7.0 10.0 , 리밸런싱발생
# >> 날짜체크 249 2018.0 7.0 11.0 , 리밸런싱발생
# >> 날짜체크 250 2018.0 7.0 12.0 , 청산조건발생
# >> 날짜체크 250 2018.0 7.0 12.0 , 리밸런싱발생
# >> 날짜체크 251 2018.0 7.0 13.0 , 리밸런싱발생
# >> 날짜체크 252 2018.0 7.0 16.0 , 리밸런싱발생
# >> 날짜체크 253 2018.0 7.0 17.0 , 리밸런싱발생
# >> 날짜체크 254 2018.0 7.0 18.0 , 청산조건발생
# >> 날짜체크 255 2018.0 7.0 19.0 , 청산조건발생
# >> 날짜체크 255 2018.0 7.0 19.0 , 리밸런싱발생
# >> 날짜체크 256 2018.0 7.0 20.0 , 리밸런싱발생
# >> 날짜체크 257 2018.0 7.0 23.0 , 리밸런싱발생
# >> 날짜체크 258 2018.0 7.0 24.0 , 리밸런싱발생
# >> 날짜체크 259 2018.0 7.0 25.0 , 리밸런싱발생
# >> 날짜체크 260 2018.0 7.0 26.0 , 리밸런싱발생
# >> 날짜체크 261 2018.0 7.0 27.0 , 리밸런싱발생
# >> 날짜체크 262 2018.0 7.0 30.0 , 리밸런싱발생
# >> 날짜체크 264 2018.0 8.0 1.0 , 리밸런싱발생
# >> 날짜체크 270 2018.0 8.0 9.0 , 청산조건발생
# >> 날짜체크 272 2018.0 8.0 13.0 , 청산조건발생
# >> 날짜체크 272 2018.0 8.0 13.0 , 리밸런싱발생
# >> 날짜체크 281 2018.0 8.0 27.0 , 청산조건발생
# >> 날짜체크 283 2018.0 8.0 29.0 , 청산조건발생
# >> 날짜체크 283 2018.0 8.0 29.0 , 리밸런싱발생
# >> 날짜체크 284 2018.0 8.0 30.0 , 리밸런싱발생
# >> 날짜체크 286 2018.0 9.0 3.0 , 리밸런싱발생
# >> 날짜체크 290 2018.0 9.0 7.0 , 청산조건발생
# >> 날짜체크 297 2018.0 9.0 18.0 , 청산조건발생
# >> 날짜체크 297 2018.0 9.0 18.0 , 리밸런싱발생
# >> 날짜체크 298 2018.0 9.0 19.0 , 청산조건발생
# >> 날짜체크 298 2018.0 9.0 19.0 , 리밸런싱발생
# >> 날짜체크 303 2018.0 10.0 1.0 , 청산조건발생
# >> 날짜체크 303 2018.0 10.0 1.0 , 리밸런싱발생
# >> 날짜체크 304 2018.0 10.0 2.0 , 청산조건발생
# >> 날짜체크 304 2018.0 10.0 2.0 , 리밸런싱발생
# >> 날짜체크 305 2018.0 10.0 4.0 , 리밸런싱발생
# >> 날짜체크 306 2018.0 10.0 5.0 , 청산조건발생
# >> 날짜체크 308 2018.0 10.0 10.0 , 청산조건발생
# >> 날짜체크 308 2018.0 10.0 10.0 , 리밸런싱발생
# >> 날짜체크 309 2018.0 10.0 11.0 , 리밸런싱발생
# >> 날짜체크 317 2018.0 10.0 23.0 , 청산조건발생
# >> 날짜체크 319 2018.0 10.0 25.0 , 청산조건발생
# >> 날짜체크 320 2018.0 10.0 26.0 , 청산조건발생
# >> 날짜체크 321 2018.0 10.0 29.0 , 청산조건발생
# >> 날짜체크 321 2018.0 10.0 29.0 , 리밸런싱발생
# >> 날짜체크 322 2018.0 10.0 30.0 , 청산조건발생
# >> 날짜체크 322 2018.0 10.0 30.0 , 리밸런싱발생
# >> 날짜체크 323 2018.0 10.0 31.0 , 리밸런싱발생
# >> 날짜체크 324 2018.0 11.0 1.0 , 리밸런싱발생
# >> 날짜체크 325 2018.0 11.0 2.0 , 리밸런싱발생
# >> 날짜체크 326 2018.0 11.0 5.0 , 리밸런싱발생
# >> 날짜체크 327 2018.0 11.0 6.0 , 리밸런싱발생
# >> 날짜체크 328 2018.0 11.0 7.0 , 리밸런싱발생
# >> 날짜체크 329 2018.0 11.0 8.0 , 리밸런싱발생
# >> 날짜체크 334 2018.0 11.0 15.0 , 청산조건발생
# >> 날짜체크 341 2018.0 11.0 26.0 , 청산조건발생
# >> 날짜체크 341 2018.0 11.0 26.0 , 리밸런싱발생
# >> 날짜체크 342 2018.0 11.0 27.0 , 리밸런싱발생
# >> 날짜체크 343 2018.0 11.0 28.0 , 리밸런싱발생
# >> 날짜체크 344 2018.0 11.0 29.0 , 리밸런싱발생
# >> 날짜체크 345 2018.0 11.0 30.0 , 리밸런싱발생
# >> 날짜체크 346 2018.0 12.0 3.0 , 리밸런싱발생
# >> 날짜체크 347 2018.0 12.0 4.0 , 리밸런싱발생
# >> 날짜체크 348 2018.0 12.0 5.0 , 청산조건발생
# >> 날짜체크 348 2018.0 12.0 5.0 , 리밸런싱발생
# >> 날짜체크 349 2018.0 12.0 6.0 , 청산조건발생
# >> 날짜체크 349 2018.0 12.0 6.0 , 리밸런싱발생
# >> 날짜체크 350 2018.0 12.0 7.0 , 리밸런싱발생
# >> 날짜체크 351 2018.0 12.0 10.0 , 리밸런싱발생
# >> 날짜체크 352 2018.0 12.0 11.0 , 리밸런싱발생
# >> 날짜체크 353 2018.0 12.0 12.0 , 리밸런싱발생
# >> 날짜체크 354 2018.0 12.0 13.0 , 리밸런싱발생
# >> 날짜체크 355 2018.0 12.0 14.0 , 리밸런싱발생
# >> 날짜체크 356 2018.0 12.0 17.0 , 리밸런싱발생
# >> 날짜체크 357 2018.0 12.0 18.0 , 리밸런싱발생
# >> 날짜체크 358 2018.0 12.0 19.0 , 리밸런싱발생
# >> 날짜체크 359 2018.0 12.0 20.0 , 리밸런싱발생
# >> 날짜체크 360 2018.0 12.0 21.0 , 리밸런싱발생
# >> 날짜체크 361 2018.0 12.0 24.0 , 리밸런싱발생
# >> 날짜체크 362 2018.0 12.0 26.0 , 리밸런싱발생
# >> 날짜체크 363 2018.0 12.0 27.0 , 리밸런싱발생
# >> 날짜체크 364 2018.0 12.0 28.0 , 리밸런싱발생
# >> 날짜체크 365 2019.0 1.0 2.0 , 리밸런싱발생
# >> 날짜체크 366 2019.0 1.0 3.0 , 리밸런싱발생
# >> 날짜체크 367 2019.0 1.0 4.0 , 리밸런싱발생
# >> 날짜체크 368 2019.0 1.0 7.0 , 리밸런싱발생
# >> 날짜체크 369 2019.0 1.0 8.0 , 리밸런싱발생
# >> 날짜체크 370 2019.0 1.0 9.0 , 리밸런싱발생
# >> 날짜체크 371 2019.0 1.0 10.0 , 리밸런싱발생
# >> 날짜체크 374 2019.0 1.0 15.0 , 청산조건발생
# >> 날짜체크 376 2019.0 1.0 17.0 , 청산조건발생
# >> 날짜체크 384 2019.0 1.0 29.0 , 청산조건발생
# >> 날짜체크 384 2019.0 1.0 29.0 , 리밸런싱발생
# >> 날짜체크 385 2019.0 1.0 30.0 , 리밸런싱발생
# >> 날짜체크 387 2019.0 2.0 1.0 , 리밸런싱발생
# >> 날짜체크 388 2019.0 2.0 7.0 , 청산조건발생
# >> 날짜체크 389 2019.0 2.0 8.0 , 청산조건발생
# >> 날짜체크 389 2019.0 2.0 8.0 , 리밸런싱발생
# >> 날짜체크 390 2019.0 2.0 11.0 , 리밸런싱발생
# >> 날짜체크 391 2019.0 2.0 12.0 , 리밸런싱발생
# >> 날짜체크 392 2019.0 2.0 13.0 , 리밸런싱발생
# >> 날짜체크 393 2019.0 2.0 14.0 , 리밸런싱발생
# >> 날짜체크 394 2019.0 2.0 15.0 , 리밸런싱발생
# >> 날짜체크 395 2019.0 2.0 18.0 , 리밸런싱발생
# >> 날짜체크 396 2019.0 2.0 19.0 , 리밸런싱발생
# >> 날짜체크 397 2019.0 2.0 20.0 , 리밸런싱발생
# >> 날짜체크 398 2019.0 2.0 21.0 , 청산조건발생
# >> 날짜체크 398 2019.0 2.0 21.0 , 리밸런싱발생
# >> 날짜체크 399 2019.0 2.0 22.0 , 리밸런싱발생
# >> 날짜체크 400 2019.0 2.0 25.0 , 리밸런싱발생
# >> 날짜체크 401 2019.0 2.0 26.0 , 리밸런싱발생
# >> 날짜체크 403 2019.0 2.0 28.0 , 청산조건발생
# >> 날짜체크 404 2019.0 3.0 4.0 , 리밸런싱발생
# >> 날짜체크 410 2019.0 3.0 12.0 , 청산조건발생
# >> 날짜체크 411 2019.0 3.0 13.0 , 청산조건발생
# >> 날짜체크 411 2019.0 3.0 13.0 , 리밸런싱발생
# >> 날짜체크 412 2019.0 3.0 14.0 , 청산조건발생
# >> 날짜체크 413 2019.0 3.0 15.0 , 청산조건발생
# >> 날짜체크 416 2019.0 3.0 20.0 , 청산조건발생
# >> 날짜체크 416 2019.0 3.0 20.0 , 리밸런싱발생
# >> 날짜체크 417 2019.0 3.0 21.0 , 리밸런싱발생
# >> 날짜체크 422 2019.0 3.0 28.0 , 청산조건발생
# >> 날짜체크 424 2019.0 4.0 1.0 , 리밸런싱발생
# >> 날짜체크 433 2019.0 4.0 12.0 , 청산조건발생
# >> 날짜체크 433 2019.0 4.0 12.0 , 리밸런싱발생
# >> 날짜체크 434 2019.0 4.0 15.0 , 리밸런싱발생
# >> 날짜체크 435 2019.0 4.0 16.0 , 리밸런싱발생
# >> 날짜체크 442 2019.0 4.0 25.0 , 청산조건발생
# >> 날짜체크 443 2019.0 4.0 26.0 , 청산조건발생
# >> 날짜체크 446 2019.0 5.0 2.0 , 리밸런싱발생
# >> 날짜체크 447 2019.0 5.0 3.0 , 청산조건발생
# >> 날짜체크 447 2019.0 5.0 3.0 , 리밸런싱발생
# >> 날짜체크 448 2019.0 5.0 7.0 , 청산조건발생
# >> 날짜체크 448 2019.0 5.0 7.0 , 리밸런싱발생
# >> 날짜체크 449 2019.0 5.0 8.0 , 청산조건발생
# >> 날짜체크 449 2019.0 5.0 8.0 , 리밸런싱발생
# >> 날짜체크 450 2019.0 5.0 9.0 , 리밸런싱발생
# >> 날짜체크 455 2019.0 5.0 16.0 , 청산조건발생
# >> 날짜체크 457 2019.0 5.0 20.0 , 청산조건발생
# >> 날짜체크 457 2019.0 5.0 20.0 , 리밸런싱발생
# >> 날짜체크 458 2019.0 5.0 21.0 , 리밸런싱발생
# >> 날짜체크 460 2019.0 5.0 23.0 , 청산조건발생
# >> 날짜체크 461 2019.0 5.0 24.0 , 청산조건발생
# >> 날짜체크 461 2019.0 5.0 24.0 , 리밸런싱발생
# >> 날짜체크 463 2019.0 5.0 28.0 , 청산조건발생
# >> 날짜체크 464 2019.0 5.0 29.0 , 청산조건발생
# >> 날짜체크 464 2019.0 5.0 29.0 , 리밸런싱발생
# >> 날짜체크 465 2019.0 5.0 30.0 , 리밸런싱발생
# >> 날짜체크 466 2019.0 5.0 31.0 , 리밸런싱발생
# >> 날짜체크 467 2019.0 6.0 3.0 , 리밸런싱발생
# >> 날짜체크 471 2019.0 6.0 10.0 , 청산조건발생
# >> 날짜체크 476 2019.0 6.0 17.0 , 청산조건발생
# >> 날짜체크 476 2019.0 6.0 17.0 , 리밸런싱발생
# >> 날짜체크 477 2019.0 6.0 18.0 , 리밸런싱발생
# >> 날짜체크 478 2019.0 6.0 19.0 , 리밸런싱발생
# >> 날짜체크 479 2019.0 6.0 20.0 , 청산조건발생
# >> 날짜체크 483 2019.0 6.0 26.0 , 청산조건발생
# >> 날짜체크 483 2019.0 6.0 26.0 , 리밸런싱발생
# >> 날짜체크 484 2019.0 6.0 27.0 , 리밸런싱발생
# >> 날짜체크 485 2019.0 6.0 28.0 , 청산조건발생
# >> 날짜체크 486 2019.0 7.0 1.0 , 리밸런싱발생
# >> 날짜체크 487 2019.0 7.0 2.0 , 청산조건발생
# >> 날짜체크 492 2019.0 7.0 9.0 , 청산조건발생
# >> 날짜체크 503 2019.0 7.0 24.0 , 청산조건발생
# >> 날짜체크 506 2019.0 7.0 29.0 , 청산조건발생
# >> 날짜체크 506 2019.0 7.0 29.0 , 리밸런싱발생
# >> 날짜체크 507 2019.0 7.0 30.0 , 리밸런싱발생
# >> 날짜체크 508 2019.0 7.0 31.0 , 청산조건발생
# >> 날짜체크 508 2019.0 7.0 31.0 , 리밸런싱발생
# >> 날짜체크 509 2019.0 8.0 1.0 , 리밸런싱발생
# >> 날짜체크 511 2019.0 8.0 5.0 , 청산조건발생
# >> 날짜체크 516 2019.0 8.0 12.0 , 청산조건발생
# >> 날짜체크 516 2019.0 8.0 12.0 , 리밸런싱발생
# >> 날짜체크 517 2019.0 8.0 13.0 , 청산조건발생
# >> 날짜체크 517 2019.0 8.0 13.0 , 리밸런싱발생
# >> 날짜체크 518 2019.0 8.0 14.0 , 리밸런싱발생
# >> 날짜체크 520 2019.0 8.0 19.0 , 청산조건발생
# >> 날짜체크 530 2019.0 9.0 2.0 , 리밸런싱발생
# >> 날짜체크 541 2019.0 9.0 19.0 , 청산조건발생
# >> 날짜체크 541 2019.0 9.0 19.0 , 리밸런싱발생
# >> 날짜체크 542 2019.0 9.0 20.0 , 리밸런싱발생
# >> 날짜체크 543 2019.0 9.0 23.0 , 리밸런싱발생
# >> 날짜체크 544 2019.0 9.0 24.0 , 리밸런싱발생
# >> 날짜체크 545 2019.0 9.0 25.0 , 리밸런싱발생
# >> 날짜체크 546 2019.0 9.0 26.0 , 리밸런싱발생
# >> 날짜체크 547 2019.0 9.0 27.0 , 리밸런싱발생
# >> 날짜체크 548 2019.0 9.0 30.0 , 리밸런싱발생
# >> 날짜체크 549 2019.0 10.0 1.0 , 리밸런싱발생
# >> 날짜체크 550 2019.0 10.0 2.0 , 리밸런싱발생
# >> 날짜체크 551 2019.0 10.0 4.0 , 리밸런싱발생
# >> 날짜체크 552 2019.0 10.0 7.0 , 청산조건발생
# >> 날짜체크 552 2019.0 10.0 7.0 , 리밸런싱발생
# >> 날짜체크 553 2019.0 10.0 8.0 , 리밸런싱발생
# >> 날짜체크 554 2019.0 10.0 10.0 , 리밸런싱발생
# >> 날짜체크 555 2019.0 10.0 11.0 , 리밸런싱발생
# >> 날짜체크 556 2019.0 10.0 14.0 , 리밸런싱발생
# >> 날짜체크 557 2019.0 10.0 15.0 , 리밸런싱발생
# >> 날짜체크 558 2019.0 10.0 16.0 , 리밸런싱발생
# >> 날짜체크 559 2019.0 10.0 17.0 , 리밸런싱발생
# >> 날짜체크 560 2019.0 10.0 18.0 , 청산조건발생
# >> 날짜체크 564 2019.0 10.0 24.0 , 청산조건발생
# >> 날짜체크 564 2019.0 10.0 24.0 , 리밸런싱발생
# >> 날짜체크 565 2019.0 10.0 25.0 , 청산조건발생
# >> 날짜체크 570 2019.0 11.0 1.0 , 리밸런싱발생
# >> 날짜체크 574 2019.0 11.0 7.0 , 청산조건발생
# 평가금액 = 169771229 , 누적수익률 = 69.77 , 연평균수익률 =  22.92 , 표준편차 = 49.94 , 샤프지수 = 0.46
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 51061 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:211: RuntimeWarning: Glyph 47456 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 49688 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 51061 missing from current font.
#   font.set_text(s, 0, flags=flags)
# /usr/local/lib/python3.6/dist-packages/matplotlib/backends/backend_agg.py:180: RuntimeWarning: Glyph 47456 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# # 변수 최적화 시뮬레이션

# %%
def call_main():
    for 기간 in range(50, 501, 50):
        for 주기 in range(1, 7):
            for 시작월 in range(주기):
                for 날짜 in range(1, 32, 10):
                    for 손절률 in range(25, 51, 5):
                        for atrs1 in range(1, 11):
                            for atrs2 in range(1, 11):
                                for atrs3 in range(1, 11):
                                    for atrs4 in range(1, 11):
                                        메인_처리(20191001, 기간, 주기, 시작월, 날짜, 손절률, atrs1, atrs2, atrs3, atrs4, 0)

# %%
call_main()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-b58c7cf14d15> in <module>()
# ----> 1 call_main()
#
# <ipython-input-32-0cfa2eb67e1f> in call_main()
#       9                                 for atrs3 in range(1, 11):
#      10                                     for atrs4 in range(1, 11):
# ---> 11                                         메인_처리(20191001, 기간, 주기, 시작월, 날짜, 손절률, atrs1, atrs2, atrs3, atrs4, 0)
#
# <ipython-input-27-194de62983d8> in 메인_처리(기준일, 공분산_산출기간, 리밸런싱_주기, 리밸런싱_시작월, 리밸런싱_날짜, 손절률, atrs1, atrs2, atrs3, atrs4, 차트출력)
#     111         if ((dd0 < 리밸런싱_날짜 <= dd or 리밸런싱_날짜 <= dd < dd0 or dd1 < dd <= 리밸런싱_날짜)             and mm % 리밸런싱_주기 == 리밸런싱_시작월) or             보유종목수 <= 2:
#     112             print(">> 날짜체크", i, yyyy, mm, dd, ", 리밸런싱발생")
# --> 113             opt_result, W = 포트폴리오생성(i,청산조건발생종목)
#     114             if opt_result == True:  # 포트폴리오 생성이 정상이라면
#     115                 현금 = 평가금액_테이블.iloc[i, 현금칼럼]
#
# <ipython-input-24-9485cac5701e> in 포트폴리오생성(row_num, 청산조건발생종목)
#      26         bnds = tuple((0, 1) for x in range(noa))
#      27
# ---> 28         opts = sco.minimize(min_func_sharpe, noa * [1. / noa, ], (R, C), method='SLSQP', bounds=bnds, constraints=cons)
#      29         optsx = (opts['x'] * 100).round(3)  # 샤프지수 최대 포트폴리오 결과값
#      30         jj = 0
#
# /usr/local/lib/python3.6/dist-packages/scipy/optimize/_minimize.py in minimize(fun, x0, args, method, jac, hess, hessp, bounds, constraints, tol, callback, options)
#     606     elif meth == 'slsqp':
#     607         return _minimize_slsqp(fun, x0, args, jac, bounds,
# --> 608                                constraints, callback=callback, **options)
#     609     elif meth == 'trust-constr':
#     610         return _minimize_trustregion_constr(fun, x0, args, jac, hess, hessp,
#
# /usr/local/lib/python3.6/dist-packages/scipy/optimize/slsqp.py in _minimize_slsqp(func, x0, args, jac, bounds, constraints, maxiter, ftol, iprint, disp, eps, callback, **unknown_options)
#     421             # Compute the derivatives of the objective function
#     422             # For some reason SLSQP wants g dimensioned to n+1
# --> 423             g = append(fprime(x), 0.0)
#     424
#     425             # Compute the normals of the constraints
#
# /usr/local/lib/python3.6/dist-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     325     def function_wrapper(*wrapper_args):
#     326         ncalls[0] += 1
# --> 327         return function(*(wrapper_args + args))
#     328
#     329     return ncalls, function_wrapper
#
# /usr/local/lib/python3.6/dist-packages/scipy/optimize/slsqp.py in approx_jacobian(x, func, epsilon, *args)
#      61     for i in range(len(x0)):
#      62         dx[i] = epsilon
# ---> 63         jac[i] = (func(*((x0+dx,)+args)) - f0)/epsilon
#      64         dx[i] = 0.0
#      65
#
# /usr/local/lib/python3.6/dist-packages/scipy/optimize/optimize.py in function_wrapper(*wrapper_args)
#     325     def function_wrapper(*wrapper_args):
#     326         ncalls[0] += 1
# --> 327         return function(*(wrapper_args + args))
#     328
#     329     return ncalls, function_wrapper
#
# <ipython-input-22-f3f1169e00ed> in min_func_sharpe(w, r, c)
#       1 def min_func_sharpe(w,r,c):
#       2 # 최소화문제에서 샤프지수 최대값을 찾으려면 샤프지수의 음수 값을 최소화하면 된다.
# ----> 3     return -statistics(w,r,c)[2]  # 위에서 만든 statistics의 3번째 값이 샤프지수
#
# <ipython-input-21-ff4d85341a2d> in statistics(w, r, c)
#      13     w = np.array(w)
#      14     portfolio_return = np.sum(r * w)
# ---> 15     portfolio_volatility = np.sqrt(np.dot(w.T,np.dot(c, w)))
#      16     sharp_ratio = portfolio_return / portfolio_volatility
#      17     return np.array([portfolio_return, portfolio_volatility, sharp_ratio])
#
# KeyboardInterrupt:
